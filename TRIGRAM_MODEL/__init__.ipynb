# %%
"""
Trigram Language Model Package
"""

from .ngram_model import TrigramModel

__version__ = "1.0.0"
__all__ = ["TrigramModel"]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       1 """
#       2 Trigram Language Model Package
#       3 """
# ----> 5 from .ngram_model import TrigramModel
#       7 __version__ = "1.0.0"
#       8 __all__ = ["TrigramModel"]
#
# ImportError: attempted relative import with no known parent package
